# %%
import pandas as pd

# %%
df = pd.read_csv('grid_search_results.csv')

# %%
df.head()
# Out:
#                                 experiment  100_samples:val_10%_accuracy  \
# 0  lr0.10_decay1pct_bs16_layers100-50-25-3                           1.0
# 1   lr0.10_decay1pct_bs8_layers100-50-25-3                           1.0
# 2  lr0.10_decay2pct_bs16_layers100-50-25-3                           1.0
# 3   lr0.10_decay2pct_bs8_layers100-50-25-3                           1.0
# 4  lr0.10_decay5pct_bs16_layers100-50-25-3                           1.0
#
#    100_samples:val_10%_val_loss_mean  100_samples:val_10%_val_loss_final  \
# 0                           0.035399                            0.001581
# 1                           0.029566                            0.001278
# 2                           0.035392                            0.001416
# 3                           0.033789                            0.001397
# 4                           0.036951                            0.001457
#
#    100_samples:val_20%_accuracy  100_samples:val_20%_val_loss_mean  \
# ...

# %%
len(df)
# Out:
# 150
